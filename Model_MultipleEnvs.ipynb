# %%
import numpy as np
import pandas as pd
import datetime as dt
import globalParameters
from gurobipy import *
from Environments.chargeEnvironment import chargeEnv
import matplotlib.pyplot as plt
from Environments.chargeSetParams import charge_SetParams

# %%
# Definicion de los parametros del entorno gurobi

#Dado el número de variables de este modelo, es necesario utilizar gurobi con una licencia académica (se obtiene gratuitamente en la web de gurobi)
params = globalParameters.params
env = Env(params = params)
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2489204
# Academic license 2489204 - for non-commercial use only - registered to 80___@unizar.es

# %%
# Definición de los parámetros del problema
BOM, MixedItems, PurchaseItems, RouteItems, Orders, Stock, Tenv = chargeEnv(mode = "default")

Available_Stock = True
if not Available_Stock:
    Stock["STOCK"] = 0

Param_MOQ = False
if Param_MOQ:
    NN, K1, K2, K3, LEVEL0, N, N_reverse, layers, R, T, D, B, item_indices, customer_indices, c_act, c1, c2, MOQ1, MOQ2, lt, ltf, I_0, alpha = charge_SetParams(BOM, MixedItems, PurchaseItems, RouteItems, Orders, Stock, Tenv)
else:
    NN, K1, K2, K3, LEVEL0, N, N_reverse, layers, R, T, D, B, item_indices, customer_indices, c_act, c1, c2, _, _, lt, ltf, I_0, alpha = charge_SetParams(BOM, MixedItems, PurchaseItems, RouteItems, Orders, Stock, Tenv)

# %%
# Inicialización del modelo
modelo = Model("Ejercicio", env = env)

# %%
# Definición de las variables
indices_x = [(i,t) for t in range(1,len(T)) for i in K1+K3]
indices_z1 = [(i,t) for t in range(1,len(T))  for i in K1+K3]
indices_y = [(i,t) for t in range(1,len(T))  for i in K2+K3]
indices_z2 = [(i,t) for t in range(1,len(T))  for i in K2+K3]
indices_w = [(i, r, t) for t in range(1,len(T))  for i in LEVEL0 for r in R]
indices_I = [(i,t) for t in range(1,len(T))  for i in NN]

x = modelo.addVars(indices_x, lb = 0, vtype = GRB.INTEGER, name = "x") 
z1 = modelo.addVars(indices_z1, lb = 0, vtype = GRB.BINARY, name = "z1")
y = modelo.addVars(indices_y, lb = 0, vtype = GRB.INTEGER, name = "y")
z2 = modelo.addVars(indices_z2, lb = 0, vtype = GRB.BINARY, name = "z2")
w = modelo.addVars(indices_w, lb = 0, vtype= GRB.BINARY, name = "w") 
It =  modelo.addVars(indices_I, lb = 0, vtype= GRB.INTEGER, name = "It")

if not Param_MOQ:
    MOQ1_indices = [i for i in K1+K3]
    MOQ2_indices = [i for i in K2+K3]
    MOQ1 = modelo.addVars(MOQ1_indices, lb = 0, vtype= GRB.INTEGER, name = "MOQ1") 
    MOQ2 =  modelo.addVars(MOQ2_indices, lb = 0, vtype= GRB.INTEGER, name = "MOQ2")

modelo.update()

# %%
# Inventario para el primer periodo, para items a nivel 0
for i in set(K1).intersection(set(LEVEL0)):
    if ltf[i] < 1:
        modelo.addConstr(
            It[i,1] == I_0[i] + x[i, 1-ltf[i]] - quicksum(D[1][item_indices[i],customer_indices[r]]*w[i,r,1] for r in R),
            name=f"R10a_{i}"
        )
    if ltf[i] >= 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
            name=f"R10b_{i}"
        )
for i in set(K2).intersection(set(LEVEL0)):
    if lt[i] < 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] + y[i, 1-lt[i]] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
            name=f"R20_{i}"
        )
    if lt[i] >= 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
            name=f"R30_{i}"
        )   
for i in set(K3).intersection(set(LEVEL0)):
    if lt[i] < 1:
        if ltf[i]<1:
            modelo.addConstr(
                It[i, 1] == I_0[i] + x[i, 1-ltf[i]] + y[i, 1-lt[i]] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
                name=f"R401_{i}"
            )
        else:
            modelo.addConstr(
                It[i, 1] == I_0[i] + y[i, 1-lt[i]] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
                name=f"R402_{i}"
            )
    else:
        if ltf[i]<1:            
            modelo.addConstr(
                It[i, 1] == I_0[i] + x[i, 1-ltf[i]] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
                name=f"R501_{i}"
            )
        else:
            modelo.addConstr(
                It[i, 1] == I_0[i] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
                name=f"R502_{i}"
            )
        
    

# Inventario para el primer periodo, para items a otro nivel
for i in set(K1).intersection(set().union(*layers[1:])):
    if ltf[i] < 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] + x[i, 1-ltf[i]] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
            name=f"R1a_{i}"
        )
    else:
        modelo.addConstr(
            It[i, 1] == I_0[i] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
            name=f"R1b_{i}"
        )
for i in set(K2).intersection(set().union(*layers[1:])):
    if lt[i] < 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] + y[i, 1-lt[i]] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
            name=f"R2a_{i}"
        )
    if lt[i] >= 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
            name=f"R3a_{i}"
        )
for i in set(K3).intersection(set().union(*layers[1:])):
    if lt[i] < 1:
        if ltf[i] < 1:
            modelo.addConstr(
                It[i, 1] == I_0[i] + x[i, 1-ltf[i]] + y[i, 1-lt[i]] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
                name=f"R4a1_{i}"
            )
        else:
            modelo.addConstr(
                It[i, 1] == I_0[i] + y[i, 1-lt[i]] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
                name=f"R4a2_{i}"
            )
    else:
        if ltf[i] < 1:
            modelo.addConstr(
                It[i, 1] == I_0[i] + x[i, 1-ltf[i]] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
                name=f"R5a1_{i}"
            )
        else:
            modelo.addConstr(
                It[i, 1] == I_0[i] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
                name=f"R5a2_{i}"
            )
    

# Inventario para el resto de periodos, para items a nivel 0
for i in set(K1).intersection(set(LEVEL0)):
    for t in range(2, len(T)):
        if ltf[i] < t:
            modelo.addConstr(
                It[i, t] == It[i, t-1] + x[i, t-ltf[i]] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                name=f"R10ta_{i}_{t}"
            )
        else:
            modelo.addConstr(
                It[i, t] == It[i, t-1] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                name=f"R10tb_{i}_{t}"
            )
for i in set(K2).intersection(set(LEVEL0)):
    for t in range(2, len(T)):
        if lt[i] < t:
            modelo.addConstr(
                It[i, t] == It[i, t-1] + y[i, t-lt[i]] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                name=f"R20t_{i}_{t}"
            )
        else:
            modelo.addConstr(
                It[i, t] == It[i, t-1] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                name=f"R30t_{i}_{t}"
            )
for i in set(K3).intersection(set(LEVEL0)):
    for t in range(2, len(T)):
        if lt[i] < t:
            if ltf[i] < t:
                modelo.addConstr(
                    It[i, t] == It[i, t-1] + x[i, t-ltf[i]] + y[i, t-lt[i]] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                    name=f"R40t1_{i}"
                )
            else:
                modelo.addConstr(
                    It[i, t] == It[i, t-1] + y[i, t-lt[i]] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                    name=f"R40t2_{i}"
                )
        else:
            if ltf[i] < t:            
                modelo.addConstr(
                    It[i, t] == It[i, t-1] + x[i, t-ltf[i]] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                    name=f"R50t1_{i}"
                )
            else:
                modelo.addConstr(
                    It[i, t] == It[i, t-1] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                    name=f"R50t2_{i}"
                )

# Inventario para el resto de periodos, para items a otro nivel
for i in set(K1).intersection(set().union(*layers[1:])):
    for t in range(2, len(T)):
        if ltf[i] < t:
            modelo.addConstr(
                It[i, t] == It[i, t-1] + x[i, t-ltf[i]] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                name=f"R1atb_{i}_{t}"
            )
        else:
            modelo.addConstr(
                It[i, t] == It[i, t-1] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                name=f"R1atb_{i}_{t}"
            )
for i in set(K2).intersection(set().union(*layers[1:])):
    for t in range(2, len(T)):
        if lt[i] < t:
            modelo.addConstr(
                It[i, t] == It[i, t-1] + y[i, t-lt[i]] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                name=f"R2at_{i}_{t}"
            )
        else:
            modelo.addConstr(
                It[i, t] == It[i, t-1] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                name=f"R3at_{i}_{t}"
            )
for i in set(K3).intersection(set().union(*layers[1:])):
    for t in range(2, len(T)):
        if lt[i] < t:
            if ltf[i] < t:
                modelo.addConstr(
                    It[i, t] == It[i, t-1] + x[i, t-ltf[i]] + y[i, t-lt[i]] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                    name=f"R4at1_{i}_{t}"
                )
            else:
                modelo.addConstr(
                    It[i, t] == It[i, t-1] + y[i, t-lt[i]] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                    name=f"R4at2_{i}_{t}"
                )
        else:
            if ltf[i] < t:
                modelo.addConstr(
                    It[i, t] == It[i, t-1] + x[i, t-ltf[i]] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                    name=f"R5at1_{i}_{t}"
                )
            else:
                modelo.addConstr(
                    It[i, t] == It[i, t-1] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                    name=f"R5at2_{i}_{t}"
                )


# Restricciones de MOQs

r6 = modelo.addConstrs(
    (x[i,t] + 42000*(1-z1[i,t])>=MOQ1[i] for i in K1+K3 for t in range(1, len(T))
     ),name="R6" )
r7 = modelo.addConstrs(
    (y[i,t] + 42000*(1-z2[i,t])>= MOQ2[i] for i in K2+K3 for t in range(1, len(T))
     ),name="R7" )

# Restricciones de activacion de variables binarias
r8 = modelo.addConstrs(
    (x[i,t] <= z1[i,t]*42000 for i in K1+K3 for t in range(1, len(T))
     ),name="R8" )
r9 = modelo.addConstrs(
    (y[i,t] <= z2[i,t]*42000 for i in K2+K3 for t in range(1, len(T))
     ),name="R9" )

modelo.update()

# %%
# Definición de la función objetivo
modelo.setObjective(quicksum(quicksum(D[t][item_indices[i],customer_indices[r]]*B[t][item_indices[i],customer_indices[r]]*w[i,r,t] for r in R for i in LEVEL0) 
                             - quicksum(c1[i]*x[i,t] for i in K1+K3)
                             - quicksum(c2[i]*y[i,t] for i in K2+K3)
                             - quicksum(c_act[i]*z1[i,t] for i in K1+K3)
                             for t in range(1, len(T))), sense = GRB.MAXIMIZE)

# %%
# Optimizacion
modelo.optimize()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-12650H, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2489204 - for non-commercial use only - registered to 80___@unizar.es
# Optimize a model with 3840 rows, 37645 columns and 12486 nonzeros
# Model fingerprint: 0xbf51f429
# Variable types: 0 continuous, 37645 integer (35148 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+04]
#   Objective range  [9e-02, 6e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 4e+04]
# Presolve removed 3310 rows and 36182 columns
# Presolve time: 0.02s
# Presolved: 530 rows, 1463 columns, 3467 nonzeros
# Variable types: 0 continuous, 1463 integer (147 binary)
#
# Root relaxation: objective 4.704373e+06, 712 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 
#  2792173 2633203 4695858.32 6102    2 4656209.25 4695858.32  0.85%   1.6  390s
#  2807059 2644750 4695106.07 6798   17 4656209.25 4695858.32  0.85%   1.6  395s
#  2817976 2655695 4694321.83 7408   10 4656209.25 4695858.32  0.85%   1.6  401s
#  2829290 2668294 4693487.98 8062   10 4656209.25 4695858.32  0.85%   1.6  405s
#  2842424 2680339 infeasible 8804      4656209.25 4695858.32  0.85%   1.6  410s
#  2851059 2694744 4695858.32 3876   19 4656209.25 4695858.32  0.85%   1.6  416s
#  2864703 2702461 4695321.97 4891   19 4656209.25 4695858.32  0.85%   1.6  420s
#  2873513 2716611 4694743.12 5348   17 4656209.25 4695858.32  0.85%   1.6  427s
#  2886416 2723347 4693763.92 6116   17 4656209.25 4695858.32  0.85%   1.6  430s
#  2901477 2738988 4695858.32 5314    2 4656209.25 4695858.32  0.85%   1.6  435s
#  2913989 2751130 4695858.32 5706   19 4656209.25 4695858.32  0.85%   1.6  440s
#  2931801 2769144 4695725.72 6311    2 4656209.25 4695858.32  0.85%   1.6  445s
#  2942733 2779986 4695103.52 6799    2 4656209.25 4695858.32  0.85%   1.6  450s
#  2960011 2796569 4694125.48 7565   10 4656209.25 4695858.32  0.85%   1.6  455s
#  2977891 2812983 4693166.84 7859    2 4656209.25 4695858.32  0.85%   1.6  460s
#  2993641 2828914 4690618.67 8188   10 4656209.25 4695858.32  0.85%   1.6  465s
#  3008168 2839900 4695858.32 1978   18 4656209.25 4695858.32  0.85%   1.6  470s
#  3020085 2847333 infeasible 2398      4656209.25 4695858.32  0.85%   1.6  475s
#  3032253 2856799 4679644.61 2796   20 4656209.25 4695858.32  0.85%   1.6  480s
#
# Cutting planes:
#   Gomory: 2
#   MIR: 8
#   StrongCG: 1
#   Inf proof: 11
#
# Explored 3033615 nodes (4911441 simplex iterations) in 483.95 seconds (84.76 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 4.65621e+06 4.65621e+06 -1.2379e+07 ... -3.03706e+07
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.656209250408e+06, best bound 4.656209250408e+06, gap 0.0000%

# %%
# for t in range(1,len(T)+1):
#     for i in K1+K3:
#         if z1[i,t].X!=0:
#             print(i,t)
#             print(x[i,t].X)
            
# for t in range(1,len(T)+1):
#     for i in K2+K3:
#         if z2[i,t].X!=0:
#             print(i,t)
#             print(y[i,t].X)

for t in range(1, len(T)):
    for i in LEVEL0:
        for r in R:
            if w[i, r, t].X != 0 and D[t][item_indices[i],customer_indices[r]] != 0:
                print(f"Item, cliente, horizonte temporal: {i, r, t}")
                print(f"Demanda {D[t][item_indices[i],customer_indices[r]]}")
                if t == 1:
                    print(f"Stock antes: {I_0[i]}")
                else:
                    print(f"Stock antes: {It[i,t-1].X}")
                print(f"Stock despues: {It[i,t].X}")
                if i in K1+K3:
                    print(f"Cantidad Producida {x[i,t].X}")
                if i in K2+K3:
                    print(f"Cantidad Comprada {y[i,t].X}")
                    if lt[i]<t:
                        print(f"Cantidad comprada previamente que llega ahora {y[i,t-lt[i]].X}")
                    if i in K2:
                        lead_time = PurchaseItems.loc[PurchaseItems["MyBOMITEMID"] == i, "LEADTIME"].values[0]
                    if i in K3:
                        lead_time = MixedItems.loc[MixedItems["MyBOMITEMID"] == i, "LEADTIME"].values[0]
                    print(f"Lead time {lead_time}")
            else:
                if D[t][item_indices[i],customer_indices[r]] != 0:
                    print(f"Item, cliente, horizonte temporal: {i, r, t}")
                    print(f"NO SE SATISFACE")
    print("------------------------------------------")
# Out:
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# Item, cliente, horizonte temporal: (3, '101695', 7)
# Demanda 23.0
# Stock antes: 997.0
# Stock despues: 974.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (23, '101371', 7)
# Demanda 270.0
# Stock antes: 2322.0
# Stock despues: 1777.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101706', 7)
# Demanda 275.0
# Stock antes: 2322.0
# Stock despues: 1777.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (36, '777774', 7)
# Demanda 1133.0
# Stock antes: 233.0
# Stock despues: 0.0
# Cantidad Producida 900.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (37, '101695', 7)
# Demanda 37.0
# Stock antes: 1158.0
# Stock despues: 1325.0
# Cantidad Producida 204.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '101826', 7)
# Demanda 127.0
# Stock antes: 256.0
# Stock despues: 3428.0
# Cantidad Producida 4545.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105542', 7)
# Demanda 191.0
# Stock antes: 256.0
# Stock despues: 3428.0
# Cantidad Producida 4545.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105667', 7)
# Demanda 509.0
# Stock antes: 256.0
# Stock despues: 3428.0
# Cantidad Producida 4545.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '500090', 7)
# Demanda 546.0
# Stock antes: 256.0
# Stock despues: 3428.0
# Cantidad Producida 4545.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (41, '101169', 7)
# Demanda 95.0
# Stock antes: 271.0
# Stock despues: 106.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (41, '101382', 7)
# Demanda 55.0
# Stock antes: 271.0
# Stock despues: 106.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (41, '102349', 7)
# Demanda 15.0
# Stock antes: 271.0
# Stock despues: 106.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (42, '777776', 7)
# Demanda 658.0
# Stock antes: 89.0
# Stock despues: 387.0
# Cantidad Producida 956.0
# Item, cliente, horizonte temporal: (43, '777777', 7)
# Demanda 412.0
# Stock antes: 412.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (45, '102349', 7)
# Demanda 560.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 560.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (50, '105352', 7)
# Demanda 149.0
# Stock antes: 914.0
# Stock despues: 765.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (51, '000877', 7)
# Demanda 117.0
# Stock antes: 781.0
# Stock despues: 581.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101062', 7)
# Demanda 52.0
# Stock antes: 781.0
# Stock despues: 581.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101765', 7)
# Demanda 19.0
# Stock antes: 781.0
# Stock despues: 581.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101822', 7)
# Demanda 12.0
# Stock antes: 781.0
# Stock despues: 581.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (52, '105352', 7)
# NO SE SATISFACE
# ------------------------------------------
# Item, cliente, horizonte temporal: (2, '777771', 8)
# Demanda 28.0
# Stock antes: 1334.0
# Stock despues: 1306.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (23, '100195', 8)
# Demanda 99.0
# Stock antes: 1777.0
# Stock despues: 1474.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101345', 8)
# Demanda 41.0
# Stock antes: 1777.0
# Stock despues: 1474.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101376', 8)
# Demanda 51.0
# Stock antes: 1777.0
# Stock despues: 1474.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101775', 8)
# Demanda 77.0
# Stock antes: 1777.0
# Stock despues: 1474.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '105378', 8)
# Demanda 35.0
# Stock antes: 1777.0
# Stock despues: 1474.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (24, '101420', 8)
# Demanda 278.0
# Stock antes: 516.0
# Stock despues: 238.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (34, '001379', 8)
# Demanda 84.0
# Stock antes: 1962.0
# Stock despues: 1696.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (34, '001525', 8)
# Demanda 24.0
# Stock antes: 1962.0
# Stock despues: 1696.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (34, '100658', 8)
# Demanda 51.0
# Stock antes: 1962.0
# Stock despues: 1696.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (34, '100891', 8)
# Demanda 62.0
# Stock antes: 1962.0
# Stock despues: 1696.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (34, '105688', 8)
# Demanda 45.0
# Stock antes: 1962.0
# Stock despues: 1696.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (36, '777774', 8)
# Demanda 584.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 584.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (37, '101695', 8)
# Demanda 1871.0
# Stock antes: 1325.0
# Stock despues: 978.0
# Cantidad Producida 1524.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (38, '101528', 8)
# Demanda 456.0
# Stock antes: 1073.0
# Stock despues: 617.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (39, '777775', 8)
# Demanda 97.0
# Stock antes: 1566.0
# Stock despues: 1469.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '101826', 8)
# Demanda 116.0
# Stock antes: 3428.0
# Stock despues: 2940.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105542', 8)
# Demanda 311.0
# Stock antes: 3428.0
# Stock despues: 2940.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105667', 8)
# Demanda 31.0
# Stock antes: 3428.0
# Stock despues: 2940.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '500090', 8)
# Demanda 30.0
# Stock antes: 3428.0
# Stock despues: 2940.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (42, '777776', 8)
# Demanda 55.0
# Stock antes: 387.0
# Stock despues: 332.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (43, '777777', 8)
# Demanda 720.0
# Stock antes: 0.0
# Stock despues: 3121.0
# Cantidad Producida 3841.0
# Item, cliente, horizonte temporal: (49, '103858', 8)
# Demanda 13.0
# Stock antes: 665.0
# Stock despues: 652.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (50, '105352', 8)
# Demanda 159.0
# Stock antes: 765.0
# Stock despues: 606.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (51, '101525', 8)
# Demanda 79.0
# Stock antes: 581.0
# Stock despues: 567.0
# Cantidad Producida 1.0
# Cantidad Comprada 212.0
# Cantidad comprada previamente que llega ahora 212.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '103960', 8)
# Demanda 148.0
# Stock antes: 581.0
# Stock despues: 567.0
# Cantidad Producida 1.0
# Cantidad Comprada 212.0
# Cantidad comprada previamente que llega ahora 212.0
# Lead time 0
# Item, cliente, horizonte temporal: (52, '105352', 8)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101958', 8)
# NO SE SATISFACE
# ------------------------------------------
# Item, cliente, horizonte temporal: (3, '101695', 9)
# Demanda 159.0
# Stock antes: 974.0
# Stock despues: 815.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (4, '777772', 9)
# Demanda 479.0
# Stock antes: 69.0
# Stock despues: 0.0
# Cantidad Producida 410.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (23, '101326', 9)
# Demanda 62.0
# Stock antes: 1474.0
# Stock despues: 1412.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (37, '101695', 9)
# Demanda 457.0
# Stock antes: 978.0
# Stock despues: 521.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal:
0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (42, '777776', 10)
# Demanda 77.0
# Stock antes: 77.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (43, '777777', 10)
# Demanda 69.0
# Stock antes: 896.0
# Stock despues: 827.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (49, '101775', 10)
# Demanda 22.0
# Stock antes: 22.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (50, '105352', 10)
# Demanda 1139.0
# Stock antes: 2387.0
# Stock despues: 1248.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (51, '001519', 10)
# Demanda 140.0
# Stock antes: 567.0
# Stock despues: 181.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '001541', 10)
# Demanda 30.0
# Stock antes: 567.0
# Stock despues: 181.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '001556', 10)
# Demanda 23.0
# Stock antes: 567.0
# Stock despues: 181.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101400', 10)
# Demanda 12.0
# Stock antes: 567.0
# Stock despues: 181.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101755', 10)
# Demanda 142.0
# Stock antes: 567.0
# Stock despues: 181.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101868', 10)
# Demanda 27.0
# Stock antes: 567.0
# Stock despues: 181.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '104230', 10)
# Demanda 12.0
# Stock antes: 567.0
# Stock despues: 181.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (52, '105352', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '100078', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101142', 10)
# Demanda 15.0
# Stock antes: 55.0
# Stock despues: 24.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (53, '101467', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101507', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101559', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101647', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101842', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101861', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '102067', 10)
# Demanda 16.0
# Stock antes: 55.0
# Stock despues: 24.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (53, '103912', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '105343', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '105393', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '105807', 10)
# NO SE SATISFACE
# ------------------------------------------
# Item, cliente, horizonte temporal: (1, '001308', 11)
# Demanda 80.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 287.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (1, '001370', 11)
# Demanda 47.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 287.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (1, '100892', 11)
# Demanda 160.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 287.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (4, '777772', 11)
# Demanda 44.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 44.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (23, '000006', 11)
# Demanda 40.0
# Stock antes: 1255.0
# Stock despues: 139.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '000048', 11)
# Demanda 16.0
# Stock antes: 1255.0
# Stock despues: 139.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '000051', 11)
# Demanda 54.0
# Stock antes: 1255.0
# Stock despues: 139.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal:
0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (36, '777774', 12)
# Demanda 670.0
# Stock antes: 670.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (37, '101695', 12)
# Demanda 360.0
# Stock antes: 360.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '101826', 12)
# Demanda 588.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 2293.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105542', 12)
# Demanda 586.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 2293.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105667', 12)
# Demanda 403.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 2293.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '500090', 12)
# Demanda 716.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 2293.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (41, '101382', 12)
# Demanda 31.0
# Stock antes: 106.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (41, '102349', 12)
# Demanda 75.0
# Stock antes: 106.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (43, '777777', 12)
# Demanda 399.0
# Stock antes: 399.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (48, '101986', 12)
# Demanda 51.0
# Stock antes: 1534.0
# Stock despues: 1483.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (50, '105352', 12)
# Demanda 984.0
# Stock antes: 984.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (52, '105352', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101012', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101175', 12)
# Demanda 24.0
# Stock antes: 24.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (53, '101177', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101537', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101555', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101564', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101715', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101879', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '104236', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '105378', 12)
# NO SE SATISFACE
# ------------------------------------------

# %%
for t in range(1,len(T)):
    for i in K2+K3:
        if z2[i,t].X!=0:
            print(f"Item, horizonte temporal {i, t}")
            print(f"Cantidad comprada {y[i,t].X}")
            print(f"Lead Time {lt[i]}")
            print(f"MOQ {MOQ2[i]}")
print("------------------------------------------")
# Out:
# Item, horizonte temporal (54, 1)
# Cantidad comprada 0.0
# Lead Time 4
# MOQ 0.0
# Item, horizonte temporal (55, 1)
# Cantidad comprada 0.0
# Lead Time 4
# MOQ 0.0
# Item, horizonte temporal (56, 1)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (57, 1)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (58, 1)
# Cantidad comprada 3770.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (59, 1)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (60, 1)
# Cantidad comprada 0.0
# Lead Time 2
# MOQ 0.0
# Item, horizonte temporal (61, 1)
# Cantidad comprada 0.0
# Lead Time 2
# MOQ 0.0
# Item, horizonte temporal (62, 1)
# Cantidad comprada 42000.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (63, 1)
# Cantidad comprada 0.0
# Lead Time 4
# MOQ 0.0
# Item, horizonte temporal (64, 1)
# Cantidad comprada 0.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (65, 1)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (66, 1)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (67, 1)
# Cantidad comprada 323.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (68, 1)
# Cantidad comprada 1048.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (69, 1)
# Cantidad comprada 0.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (70, 1)
# Cantidad comprada 603.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (71, 1)
# Cantidad comprada 107.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (72, 1)
# Cantidad comprada 0.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (73, 1)
# Cantidad comprada 0.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (74, 1)
# Cantidad comprada 0.0
# Lead Time 2
# MOQ 0.0
# Item, horizonte temporal (75, 1)
# Cantidad comprada 0.0
# Lead Time 2
# MOQ 0.0
# Item, horizonte temporal (76, 1)
# Cantidad comprada 0.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (78, 1)
# Cantidad comprada 0.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (1, 1)
# Cantidad comprada 0.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (2, 1)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (3, 1)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (4, 1)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (5, 1)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (8, 1)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal
 12)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# Item, horizonte temporal (51, 12)
# Cantidad comprada 0.0
# Lead Time 0
# MOQ 0.0
# Item, horizonte temporal (77, 12)
# Cantidad comprada 0.0
# Lead Time 6
# MOQ 0.0
# ------------------------------------------

# %%
for t in range(1,len(T)):
    for i in K1+K3:
        if z1[i,t].X!=0:
            print(f"Item, horizonte temporal {i, t}")
            print(f"Cantidad producida {x[i,t].X}")
            print(f"MOQ {MOQ1[i]}")
        else:
            if x[i,t].X != 0:
                print(f"No debería producir {i, t}")
                print(f"Cantidad producida {x[i,t].X}")
# Out:
# Item, horizonte temporal (6, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 1)
# Cantidad producida 344.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 1)
# Cantidad producida 188.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 1)
# Cantidad producida 563.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 1)
# Cantidad producida 813.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 1)
# Cantidad producida 260.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 1)
# Cantidad producida 563.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 1)
# Cantidad producida 691.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 1)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 1)
# Cantidad producida 107.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 2)
# Cantidad producida 204.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 2)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 3)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 4)
# Cantidad producida 532.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 4)
# Cantidad producida 644.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 4)
# Cantidad producida 69.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 4)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 5)
# Cantidad producida 591.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 5)
# Cantidad producida 69.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 5)
# Cantidad producida 881.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 5)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 6)
# Cantidad producida 390.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 6)
# Cantidad producida 1158.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 6)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 7)
# Cantidad producida 204.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 7)
# Cantidad producida 956.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 7)
# Cantidad producida 900.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 7)
# Cantidad producida 3126.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 7)
# Cantidad producida 900.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 7)
# Cantidad producida 204.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 7)
# Cantidad producida 4545.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 7)
# Cantidad producida 560.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 7)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 7)
# Cantidad producida 323.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 8)
# Cantidad producida 1524.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 8)
# Cantidad producida 1524.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 8)
# Cantidad producida 3841.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 8)
# Cantidad producida 41.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 8)
# Cantidad producida 55.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 8)
# Cantidad producida 584.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 8)
# Cantidad producida 584.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 8)
# Cantidad producida 3841.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 8)
# Cantidad producida 3000.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 8)
# Cantidad producida 584.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 8)
# Cantidad producida 1524.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 8)
# Cantidad producida 481.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 8)
# Cantidad producida 1.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 8)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 9)
# Cantidad producida 410.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 9)
# Cantidad producida 2754.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 9)
# Cantidad producida 2754.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 9)
# Cantidad producida 1500.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 9)
# Cantidad producida 650.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 9)
# Cantidad producida 2754.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 9)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 10)
# Cantidad producida 240.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 10)
# Cantidad producida 1061.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 10)
# Cantidad producida 210.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 10)
# Cantidad producida 210.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 10)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 11)
# Cantidad producida 287.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 11)
# Cantidad producida 313.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 11)
# Cantidad producida 44.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 11)
# Cantidad producida 1107.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 11)
# Cantidad producida 1107.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 11)
# Cantidad producida 1958.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 11)
# Cantidad producida 1069.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 11)
# Cantidad producida 59.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 11)
# Cantidad producida 1834.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 11)
# Cantidad producida 644.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 11)
# Cantidad producida 1958.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 11)
# Cantidad producida 276.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 11)
# Cantidad producida 287.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 11)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>
# Item, horizonte temporal (6, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[6] (value 0.0)>
# Item, horizonte temporal (7, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[7] (value 0.0)>
# Item, horizonte temporal (15, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[15] (value 0.0)>
# Item, horizonte temporal (16, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[16] (value 0.0)>
# Item, horizonte temporal (42, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[42] (value 0.0)>
# Item, horizonte temporal (43, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[43] (value 0.0)>
# Item, horizonte temporal (46, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[46] (value 0.0)>
# Item, horizonte temporal (52, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[52] (value 0.0)>
# Item, horizonte temporal (53, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[53] (value 0.0)>
# Item, horizonte temporal (1, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[1] (value 0.0)>
# Item, horizonte temporal (2, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[2] (value 0.0)>
# Item, horizonte temporal (3, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[3] (value 0.0)>
# Item, horizonte temporal (4, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[4] (value 0.0)>
# Item, horizonte temporal (5, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[5] (value 0.0)>
# Item, horizonte temporal (8, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[8] (value 0.0)>
# Item, horizonte temporal (9, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[9] (value 0.0)>
# Item, horizonte temporal (10, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[10] (value 0.0)>
# Item, horizonte temporal (11, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[11] (value 0.0)>
# Item, horizonte temporal (12, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[12] (value 0.0)>
# Item, horizonte temporal (13, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[13] (value 0.0)>
# Item, horizonte temporal (14, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[14] (value 0.0)>
# Item, horizonte temporal (17, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[17] (value 0.0)>
# Item, horizonte temporal (18, 12)
# Cantidad producida 1500.0
# MOQ <gurobi.Var MOQ1[18] (value 0.0)>
# Item, horizonte temporal (19, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[19] (value 0.0)>
# Item, horizonte temporal (20, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[20] (value 0.0)>
# Item, horizonte temporal (21, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[21] (value 0.0)>
# Item, horizonte temporal (22, 12)
# Cantidad producida 1500.0
# MOQ <gurobi.Var MOQ1[22] (value 0.0)>
# Item, horizonte temporal (23, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[23] (value 0.0)>
# Item, horizonte temporal (24, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[24] (value 0.0)>
# Item, horizonte temporal (25, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[25] (value 0.0)>
# Item, horizonte temporal (26, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[26] (value 0.0)>
# Item, horizonte temporal (27, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[27] (value 0.0)>
# Item, horizonte temporal (28, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[28] (value 0.0)>
# Item, horizonte temporal (29, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[29] (value 0.0)>
# Item, horizonte temporal (30, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[30] (value 0.0)>
# Item, horizonte temporal (31, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[31] (value 0.0)>
# Item, horizonte temporal (32, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[32] (value 0.0)>
# Item, horizonte temporal (33, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[33] (value 0.0)>
# Item, horizonte temporal (34, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[34] (value 0.0)>
# Item, horizonte temporal (35, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[35] (value 0.0)>
# Item, horizonte temporal (36, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[36] (value 0.0)>
# Item, horizonte temporal (37, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[37] (value 0.0)>
# Item, horizonte temporal (38, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[38] (value 0.0)>
# Item, horizonte temporal (39, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[39] (value 0.0)>
# Item, horizonte temporal (40, 12)
# Cantidad producida 2293.0
# MOQ <gurobi.Var MOQ1[40] (value 0.0)>
# Item, horizonte temporal (41, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[41] (value 0.0)>
# Item, horizonte temporal (45, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[45] (value 0.0)>
# Item, horizonte temporal (47, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[47] (value 0.0)>
# Item, horizonte temporal (48, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[48] (value 0.0)>
# Item, horizonte temporal (49, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[49] (value 0.0)>
# Item, horizonte temporal (50, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[50] (value 0.0)>
# Item, horizonte temporal (51, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[51] (value 0.0)>
# Item, horizonte temporal (77, 12)
# Cantidad producida 0.0
# MOQ <gurobi.Var MOQ1[77] (value 0.0)>

# %%
NoSatisfecha = 0
totalPedidos = 0
udsNoSatisfecha = 0
totalUds = 0
for t in range(1, len(T)):
    for i in LEVEL0:
        for r in R:
            if D[t][item_indices[i],customer_indices[r]] != 0:
                if w[i, r, t].X == 0:
                    NoSatisfecha += 1
                    udsNoSatisfecha += D[t][item_indices[i],customer_indices[r]]
                totalPedidos += 1
                totalUds += D[t][item_indices[i],customer_indices[r]]


print(udsNoSatisfecha/totalUds*100)
print(NoSatisfecha/totalPedidos*100)
print(modelo.getAttr("ObjVal"))

# %%
modelo.close()
env.close()
