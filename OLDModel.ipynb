# %%
import numpy as np
import pandas as pd
import datetime as dt
from gurobipy import *
from BOM_graph.StudyBOM import GenerateGraph
from Environments.chargeEnvironment import chargeEnv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Definicion de los parametros del entorno gurobi

#Dado el número de variables de este modelo, es necesario utilizar gurobi con una licencia académica (se obtiene gratuitamente en la web de gurobi)
params = {"WLSACCESSID" : '5cbfde7e-b7bd-44e3-9e2d-fb335f5a2deb', "WLSSECRET" : 'f526471f-ed2c-462d-a933-1241228cd704', "LICENSEID" : 2489204 }
env = Env(params = params)
# Out:
# Set parameter WLSAccessID
# Set parameter WLSSecret
# Set parameter LicenseID to value 2489204
# Academic license 2489204 - for non-commercial use only - registered to 80___@unizar.es

# %%
# Definición de los parámetros del problema
BOM, MixedItems, PurchaseItems, RouteItems, Orders, Stock, Tenv = chargeEnv(mode = "default")

# Grafo
G = GenerateGraph(BOM, typeG_ND = False, connected = True)

# Items
NN = sorted(G.nodes)
NN_len = sorted(NN)
K1 = sorted(RouteItems["MyBOMITEMID"].unique().tolist())
K2 = sorted(PurchaseItems["MyBOMITEMID"].unique().tolist())
K3 = sorted(MixedItems["MyBOMITEMID"].unique().tolist())
LEVEL0 = sorted(BOM.loc[ BOM["LEVEL"] == 0,"MyBOMITEMID"].unique().tolist())

# Arcos 
arcos = sorted(G.edges)

# Layers
layers_dict = {}
for node in G.nodes:
    layer = G.nodes[node]["layer"]
    if layer not in layers_dict:
        layers_dict[layer] = []
    layers_dict[layer].append(node)
layers = [sorted(nodes) for layer, nodes in sorted(layers_dict.items())]

# Conjuntos N(i) e inversos
N = {}
# Encontrar los ítems necesarios para cada ítem i en Kt ∪ K3
for i in sorted(K1+K3):
    N[i] = [j for _, j in G.edges(i)]

N_reverse = {j: [] for j in NN}
for j, neighbors in N.items():
    for i in neighbors:
        N_reverse[i].append(j)

# Clientes
R = sorted(Orders["CUSTOMERID"].unique().tolist())
R_len = len(R)

# Periodos de tiempo en el horizonte temporal
date_range = pd.date_range(start= dt.datetime.now().strftime("%Y-%m-01"), periods= Tenv, freq='MS')
T = date_range.tolist() # De hoy a 12 meses

# Demanda y precios de venta
# LEVEL0 = layers[0]+[39]
# Map MyBOMITEMID and CUSTOMERID to indices
item_indices = {item: idx for idx, item in enumerate(LEVEL0)} # El 39 es un ítem a nivel 0 y Layer 1
customer_indices = {customer: idx for idx, customer in enumerate(R)}
D = []
B = []
for period_start in T:
    period_end = period_start + pd.DateOffset(months=1) - pd.DateOffset(days=1)  # End of the month
    period_df = Orders[(Orders['END_DATE'] >= period_start) & (Orders['END_DATE'] <= period_end)]
    
    # Create matrices for quantities and prices
    period_matrixD = np.zeros((len(LEVEL0), R_len))
    period_matrixB = np.zeros((len(LEVEL0), R_len))
    
    # Fill the matrices
    for _, row in period_df.iterrows():
        item_idx = item_indices[row['MyBOMITEMID']]
        customer_idx = customer_indices[row['CUSTOMERID']]
        period_matrixD[item_idx, customer_idx] = row['QUANTITY']
        period_matrixB[item_idx, customer_idx] = row['UNITPRICE_EUR']
    
    # Append the period matrices to the lists
    D.append(period_matrixD)
    B.append(period_matrixB)
    
# Costes 
c1 = {**dict(zip(RouteItems["MyBOMITEMID"], RouteItems["RUNTIME_COST"])), 
  **dict(zip(MixedItems["MyBOMITEMID"], MixedItems["RUNTIME_COST"]))}
c2 = {**dict(zip(PurchaseItems["MyBOMITEMID"], PurchaseItems["UNITPRICE_Compra"])), 
  **dict(zip(MixedItems["MyBOMITEMID"], MixedItems["UNITPRICE_Compra"]))}

# MOQs
MOQ1 = {**dict(zip(RouteItems["MyBOMITEMID"], RouteItems["MOQ_Fabricacion"])), 
  **dict(zip(MixedItems["MyBOMITEMID"], MixedItems["MOQ_Fabricacion"]))}
MOQ2 = {**dict(zip(PurchaseItems["MyBOMITEMID"], PurchaseItems["MOQ_Compra"])), 
  **dict(zip(MixedItems["MyBOMITEMID"], MixedItems["MOQ_Compra"]))}

# Lead times
lt = {**dict(zip(PurchaseItems["MyBOMITEMID"], PurchaseItems["LEADTIME"])), 
  **dict(zip(MixedItems["MyBOMITEMID"], MixedItems["LEADTIME"]))}

# Stock
I_0 = dict(zip(Stock["MyBOMITEMID"], Stock["STOCK"]))


# Matriz alpha
# Construir la matriz alpha
alpha = {}

for i in sorted(K1 + K3):
    alpha[i] = {}
    for j in N[i]:
        maxibo_qty = BOM[(BOM['MyPARENTBOMITEMID'] == i) & (BOM['MyBOMITEMID'] == j)]['MAXIBOQTY']
        if not maxibo_qty.empty:
            alpha[i][j] = maxibo_qty.values[0]
        else:
            alpha[i][j] = 0

# %%
# Inicialización del modelo
modelo = Model("Ejercicio", env = env)

# %%
# Definición de las variables
indices_x = [(i,t) for t in range(1,len(T)) for i in K1+K3]
indices_z1 = [(i,t) for t in range(1,len(T))  for i in K1+K3]
indices_y = [(i,t) for t in range(1,len(T))  for i in K2+K3]
indices_z2 = [(i,t) for t in range(1,len(T))  for i in K2+K3]
indices_w = [(i, r, t) for t in range(1,len(T))  for i in LEVEL0 for r in R]
indices_I = [(i,t) for t in range(1,len(T))  for i in NN]

x = modelo.addVars(indices_x, lb = 0,vtype = GRB.INTEGER, name = "x") 
z1 = modelo.addVars(indices_z1, lb = 0,vtype = GRB.BINARY, name = "z1")
y = modelo.addVars(indices_y, lb = 0, vtype = GRB.INTEGER, name = "y")
z2 = modelo.addVars(indices_z2, lb = 0,vtype = GRB.BINARY, name = "z2")
w = modelo.addVars(indices_w, lb = 0, vtype= GRB.BINARY, name = "w") 
It =  modelo.addVars(indices_I, lb = 0,vtype= GRB.INTEGER, name = "It")

modelo.update()

# %%
# Inventario para el primer periodo, para items a nivel 0
r10 = modelo.addConstrs(
    (It[i,1] == I_0[i] + x[i, 1] - quicksum(D[1][item_indices[i],customer_indices[r]]*w[i,r,1] for r in R) for i in list(set(K1).intersection(set(LEVEL0)))
    ),name="R10" )
for i in set(K2).intersection(set(LEVEL0)):
    if lt[i] < 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] + y[i, 1-lt[i]] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
            name=f"R20_{i}"
        )
    if lt[i] >= 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
            name=f"R30_{i}"
        )   
for i in set(K3).intersection(set(LEVEL0)):
    if lt[i] < 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] + x[i, 1] + y[i, 1-lt[i]] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
            name=f"R40_{i}"
        )
    if lt[i] >= 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] + x[i, 1] - quicksum(D[1][item_indices[i], customer_indices[r]] * w[i, r, 1] for r in R),
            name=f"R50_{i}"
        )
    

# Inventario para el primer periodo, para items a otro nivel
r1a = modelo.addConstrs(
    (It[i,1] == I_0[i] + x[i, 1] - quicksum(alpha[j][i]*x[j,1] for j in N_reverse[i]) for i in list(set(K1).intersection(set().union(*layers[1:])))
    ),name="R1a" )
for i in set(K2).intersection(set().union(*layers[1:])):
    if lt[i] < 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] + y[i, 1-lt[i]] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
            name=f"R2a_{i}"
        )
    if lt[i] >= 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
            name=f"R3a_{i}"
        )
for i in set(K3).intersection(set().union(*layers[1:])):
    if lt[i] < 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] + x[i, 1] + y[i, 1-lt[i]] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
            name=f"R4a_{i}"
        )
    if lt[i] >= 1:
        modelo.addConstr(
            It[i, 1] == I_0[i] + x[i, 1] - quicksum(alpha[j][i] * x[j, 1] for j in N_reverse[i]),
            name=f"R5a_{i}"
        )
    

# Inventario para el resto de periodos, para items a nivel 0
r10t = modelo.addConstrs(
    (It[i,t] == It[i, t-1] + x[i, t] - quicksum(D[t][item_indices[i],customer_indices[r]]*w[i,r,t] for r in R) for i in list(set(K1).intersection(set(LEVEL0))) for t in range(2, len(T))
    ),name="R10t" )
for i in set(K2).intersection(set(LEVEL0)):
    for t in range(2, len(T)):
        if lt[i] < t:
            modelo.addConstr(
                It[i, t] == It[i, t-1] + y[i, t-lt[i]] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                name=f"R20t_{i}_{t}"
            )
        else:
            modelo.addConstr(
                It[i, t] == It[i, t-1] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                name=f"R30t_{i}_{t}"
            )
for i in set(K3).intersection(set(LEVEL0)):
    for t in range(2, len(T)):
        if lt[i] < t:
            modelo.addConstr(
                It[i, t] == It[i, t-1] + x[i, t] + y[i, t-lt[i]] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                name=f"R40t_{i}_{t}"
            )
        else:
            modelo.addConstr(
                It[i, t] == It[i, t-1] + x[i, t] - quicksum(D[t][item_indices[i], customer_indices[r]] * w[i, r, t] for r in R),
                name=f"R50t_{i}_{t}"
            )

# Inventario para el resto de periodos, para items a otro nivel
r1at = modelo.addConstrs(
    (It[i,t] == It[i, t-1] + x[i, t] - quicksum(alpha[j][i]*x[j, t] for j in N_reverse[i]) for i in list(set(K1).intersection(set().union(*layers[1:]))) for t in range(2, len(T))
    ),name="R1at" )
for i in set(K2).intersection(set().union(*layers[1:])):
    for t in range(2, len(T)):
        if lt[i] < t:
            modelo.addConstr(
                It[i, t] == It[i, t-1] + y[i, t-lt[i]] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                name=f"R2a_{i}_{t}"
            )
        else:
            modelo.addConstr(
                It[i, t] == It[i, t-1] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                name=f"R3a_{i}_{t}"
            )
for i in set(K3).intersection(set().union(*layers[1:])):
    for t in range(2, len(T)):
        if lt[i] < t:
            modelo.addConstr(
                It[i, t] == It[i, t-1] + x[i, t] + y[i, t-lt[i]] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                name=f"R4a_{i}_{t}"
            )
        else:
            modelo.addConstr(
                It[i, t] == It[i, t-1] + x[i, t] - quicksum(alpha[j][i] * x[j, t] for j in N_reverse[i]),
                name=f"R5a_{i}_{t}"
            )


# Restricciones de MOQs

r6 = modelo.addConstrs(
    (x[i,t] >= z1[i,t]*MOQ1[i] for i in K1+K3 for t in range(1, len(T))
     ),name="R6" )
r7 = modelo.addConstrs(
    (y[i,t] >= z2[i,t]*MOQ2[i] for i in K2+K3 for t in range(1, len(T))
     ),name="R7" )

# Restricciones de activacion de variables binarias
r8 = modelo.addConstrs(
    (x[i,t] <= z1[i,t]*420000 for i in K1+K3 for t in range(1, len(T))
     ),name="R8" )
r9 = modelo.addConstrs(
    (y[i,t] <= z2[i,t]*420000 for i in K2+K3 for t in range(1, len(T))
     ),name="R9" )

modelo.update()

# %%
# Definición de la función objetivo
modelo.setObjective(quicksum(quicksum(D[t][item_indices[i],customer_indices[r]]*B[t][item_indices[i],customer_indices[r]]*w[i,r,t] for r in R for i in LEVEL0) 
                             - quicksum(c1[i]*x[i,t] for i in K1+K3)
                             - quicksum(c2[i]*y[i,t] for i in K2+K3)
                             for t in range(1, len(T))), sense = GRB.MAXIMIZE)

# %%
# Optimizacion
modelo.optimize()
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11.0 (22621.2))
#
# CPU model: 12th Gen Intel(R) Core(TM) i7-12650H, instruction set [SSE2|AVX|AVX2]
# Thread count: 10 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2489204 - for non-commercial use only - registered to 80___@unizar.es
# Optimize a model with 3840 rows, 37524 columns and 11034 nonzeros
# Model fingerprint: 0x03bd8fa2
# Variable types: 0 continuous, 37524 integer (35148 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+05]
#   Objective range  [9e-02, 6e+05]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+01, 1e+04]
# Presolve removed 2158 rows and 35738 columns
# Presolve time: 0.03s
# Presolved: 1682 rows, 1786 columns, 5167 nonzeros
# Variable types: 0 continuous, 1786 integer (793 binary)
#
# Root relaxation: objective 4.807296e+06, 655 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4807296.49    0   27          - 4807296.49      -     -    0s
# H    0     0                    4291698.7594 4807296.49  12.0%     -    0s
# H    0     0                    4291709.1532 4807296.49  12.0%     -    0s
# H    0     0                    4296144.6287 4807296.49  11.9%     -    0s
# H    0     0                    4475387.0215 4807296.49  7.42%     -    0s
#      0     0 4794786.33    0  123 4475387.02 4794786.33  7.14%     -    0s
# H    0     0                    4475394.7716 4794785.50  7.14%     -    0s
#      0     0 4794767.55    0   96 4475394.77 4794767.55  7.14%     -    0s
# H    0     0                    4475402.5218 4794766.17  7.14%     -    0s
# H    0     0                    4477672.5455 4794766.17  7.08%     -    0s
#      0     0 4794766.12    0   93 4477672.55 4794766.12  7.08%     -    0s
#      0     0 4794535.26    0   69 4477672.55 4794535.26  7.08%     -    0s
# H    0     0                    4477680.2957 4794535.26  7.08%     -    0s
#      0     0 4794039.22    0  160 4477680.30 4794039.22  7.07%     -    0s
# H    0     0                    4477688.0458 4794039.22  7.07%     -    0s
#      0     0 4794039.22    0  164 4477688.05 4794039.22  7.07%     -    0s
#      0     0 4794039.22    0  133 4477688.05 4794039.22  7.07%     -    0s
#      0     0 4794039.22    0  169 4477688.05 4794039.22  7.07%     -    0s
# H    0     0                    4633317.7682 4794039.22  3.47%     -    0s
#      0     0 4794039.22    0  147 4633317.77 4794039.22  3.47%     -    0s
# H    0     0                    4751945.5565 4794039.22  0.89%     -    0s
#      0     0 4794039.22    0  122 4751945.56 4794039.22  0.89%     -    0s
# H    0     0                    4756674.9387 4794039.22  0.79%     -    0s
#      0     2 4794039.22    0  120 4756674.94 4794039.22  0.79%     -    0s
# H   35    46                    4760892.7017 4794029.67  0.70%   6.8    0s
# H  886   990                    4760894.9817 4794029.67  0.70%   2.3    0s
# H  954   990                    4760983.4517 4794029.67  0.69%   2.2    0s
# H  960   990                    4760985.7317 4794029.67  0.69%   2.2    0s
# H  994  1086                    4762863.1617 4794029.67  0.65%   2.2    0s
#
# Cutting planes:
#   Gomory: 8
#   Cover: 2
#   Implied bound: 2
#   MIR: 14
#   StrongCG: 1
#   Flow cover: 34
#   Inf proof: 2
#   Zero half: 3
#   Network: 1
#   Relax-and-lift: 5
#
# Explored 22007 nodes (37798 simplex iterations) in 4.98 seconds (3.14 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 10: 4.76286e+06 4.76099e+06 4.76098e+06 ... 4.47768e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.762863161677e+06, best bound 4.762863161677e+06, gap 0.0000%

# %%
# for t in range(1,len(T)+1):
#     for i in K1+K3:
#         if z1[i,t].X!=0:
#             print(i,t)
#             print(x[i,t].X)
            
# for t in range(1,len(T)+1):
#     for i in K2+K3:
#         if z2[i,t].X!=0:
#             print(i,t)
#             print(y[i,t].X)

for t in range(1, len(T)):
    for i in LEVEL0:
        for r in R:
            if w[i, r, t].X != 0 and D[t][item_indices[i],customer_indices[r]] != 0:
                print(f"Item, cliente, horizonte temporal: {i, r, t}")
                print(f"Demanda {D[t][item_indices[i],customer_indices[r]]}")
                if t == 1:
                    print(f"Stock antes: {I_0[i]}")
                else:
                    print(f"Stock antes: {It[i,t-1].X}")
                print(f"Stock despues: {It[i,t].X}")
                if i in K1+K3:
                    print(f"Cantidad Producida {x[i,t].X}")
                if i in K2+K3:
                    print(f"Cantidad Comprada {y[i,t].X}")
                    if lt[i]<t:
                        print(f"Cantidad comprada previamente que llega ahora {y[i,t-lt[i]].X}")
                    if i in K2:
                        lead_time = PurchaseItems.loc[PurchaseItems["MyBOMITEMID"] == i, "LEADTIME"].values[0]
                    if i in K3:
                        lead_time = MixedItems.loc[MixedItems["MyBOMITEMID"] == i, "LEADTIME"].values[0]
                    print(f"Lead time {lead_time}")
            else:
                if D[t][item_indices[i],customer_indices[r]] != 0:
                    print(f"Item, cliente, horizonte temporal: {i, r, t}")
                    print(f"NO SE SATISFACE")
    print("------------------------------------------")
# Out:
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# ------------------------------------------
# Item, cliente, horizonte temporal: (3, '101695', 7)
# Demanda 23.0
# Stock antes: 997.0
# Stock despues: 1042.0
# Cantidad Producida 68.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (23, '101371', 7)
# Demanda 270.0
# Stock antes: 2183.0
# Stock despues: 1638.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101706', 7)
# Demanda 275.0
# Stock antes: 2183.0
# Stock despues: 1638.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (36, '777774', 7)
# Demanda 1133.0
# Stock antes: 29.0
# Stock despues: 0.0
# Cantidad Producida 1104.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (37, '101695', 7)
# Demanda 37.0
# Stock antes: 0.0
# Stock despues: 2149.0
# Cantidad Producida 2186.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '101826', 7)
# Demanda 127.0
# Stock antes: 256.0
# Stock despues: 1001.0
# Cantidad Producida 2118.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105542', 7)
# Demanda 191.0
# Stock antes: 256.0
# Stock despues: 1001.0
# Cantidad Producida 2118.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105667', 7)
# Demanda 509.0
# Stock antes: 256.0
# Stock despues: 1001.0
# Cantidad Producida 2118.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '500090', 7)
# Demanda 546.0
# Stock antes: 256.0
# Stock despues: 1001.0
# Cantidad Producida 2118.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (41, '101169', 7)
# Demanda 95.0
# Stock antes: 311.0
# Stock despues: 146.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (41, '101382', 7)
# Demanda 55.0
# Stock antes: 311.0
# Stock despues: 146.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (41, '102349', 7)
# Demanda 15.0
# Stock antes: 311.0
# Stock despues: 146.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (42, '777776', 7)
# Demanda 658.0
# Stock antes: 1045.0
# Stock despues: 387.0
# Cantidad Producida -0.0
# Item, cliente, horizonte temporal: (43, '777777', 7)
# Demanda 412.0
# Stock antes: 22.0
# Stock despues: 720.0
# Cantidad Producida 1110.0
# Item, cliente, horizonte temporal: (45, '102349', 7)
# Demanda 560.0
# Stock antes: 0.0
# Stock despues: 768.0
# Cantidad Producida 1328.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (50, '105352', 7)
# Demanda 149.0
# Stock antes: 223.0
# Stock despues: 74.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (51, '000877', 7)
# Demanda 117.0
# Stock antes: 781.0
# Stock despues: 581.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101062', 7)
# Demanda 52.0
# Stock antes: 781.0
# Stock despues: 581.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101765', 7)
# Demanda 19.0
# Stock antes: 781.0
# Stock despues: 581.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101822', 7)
# Demanda 12.0
# Stock antes: 781.0
# Stock despues: 581.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (52, '105352', 7)
# Demanda 1251.0
# Stock antes: 1450.0
# Stock despues: 199.0
# Cantidad Producida 0.0
# ------------------------------------------
# Item, cliente, horizonte temporal: (2, '777771', 8)
# Demanda 28.0
# Stock antes: 1334.0
# Stock despues: 1306.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (23, '100195', 8)
# Demanda 99.0
# Stock antes: 1638.0
# Stock despues: 1335.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101345', 8)
# Demanda 41.0
# Stock antes: 1638.0
# Stock despues: 1335.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101376', 8)
# Demanda 51.0
# Stock antes: 1638.0
# Stock despues: 1335.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101775', 8)
# Demanda 77.0
# Stock antes: 1638.0
# Stock despues: 1335.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '105378', 8)
# Demanda 35.0
# Stock antes: 1638.0
# Stock despues: 1335.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (24, '101420', 8)
# Demanda 278.0
# Stock antes: 516.0
# Stock despues: 238.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (34, '001379', 8)
# Demanda 84.0
# Stock antes: 1962.0
# Stock despues: 1696.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (34, '001525', 8)
# Demanda 24.0
# Stock antes: 1962.0
# Stock despues: 1696.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (34, '100658', 8)
# Demanda 51.0
# Stock antes: 1962.0
# Stock despues: 1696.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (34, '100891', 8)
# Demanda 62.0
# Stock antes: 1962.0
# Stock despues: 1696.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (34, '105688', 8)
# Demanda 45.0
# Stock antes: 1962.0
# Stock despues: 1696.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (36, '777774', 8)
# Demanda 584.0
# Stock antes: 0.0
# Stock despues: 2168.0
# Cantidad Producida 2752.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (37, '101695', 8)
# Demanda 1871.0
# Stock antes: 2149.0
# Stock despues: 978.0
# Cantidad Producida 700.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (38, '101528', 8)
# Demanda 456.0
# Stock antes: 1073.0
# Stock despues: 617.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (39, '777775', 8)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (40, '101826', 8)
# Demanda 116.0
# Stock antes: 1001.0
# Stock despues: 513.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105542', 8)
# Demanda 311.0
# Stock antes: 1001.0
# Stock despues: 513.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105667', 8)
# Demanda 31.0
# Stock antes: 1001.0
# Stock despues: 513.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '500090', 8)
# Demanda 30.0
# Stock antes: 1001.0
# Stock despues: 513.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (42, '777776', 8)
# Demanda 55.0
# Stock antes: 387.0
# Stock despues: 332.0
# Cantidad Producida -0.0
# Item, cliente, horizonte temporal: (43, '777777', 8)
# Demanda 720.0
# Stock antes: 720.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Item, cliente, horizonte temporal: (49, '103858', 8)
# Demanda 13.0
# Stock antes: 802.0
# Stock despues: 789.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (50, '105352', 8)
# Demanda 159.0
# Stock antes: 74.0
# Stock despues: 2376.0
# Cantidad Producida 2461.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (51, '101525', 8)
# Demanda 79.0
# Stock antes: 581.0
# Stock despues: 354.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '103960', 8)
# Demanda 148.0
# Stock antes: 581.0
# Stock despues: 354.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 0
# Item, cliente, horizonte temporal: (52, '105352', 8)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101958', 8)
# NO SE SATISFACE
# ------------------------------------------
# Item, cliente, horizonte temporal: (3, '101695', 9)
# Demanda 159.0
# Stock antes: 1042.0
# Stock despues: 883.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (4, '777772', 9)
# Demanda 479.0
# Stock antes: 1.0
# Stock despues: -0.0
# Cantidad Producida 478.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (23, '101326', 9)
# Demanda 62.0
# Stock antes: 1335.0
# Stock despues: 1273.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (37, '101695', 9)
# Demanda 457.0
# Stock antes: 978.0
# Stock despues: 521.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '101826', 9)
# Demanda 258.0
# Stock antes: 513.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105542', 9)
# Demanda 122.0
# Stock antes: 513.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105667', 9)
# Demanda 85.0
# Stock antes: 513.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '500090', 9)
# Demanda 48.0
# Stock antes: 513.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (42, '777776', 9)
# Demanda 255.0
# Stock antes: 332.0
# Stock despues: 77.0
# Cantidad Producida -0.0
# Item, cliente, horizonte temporal: (43, '777777', 9)
# Demanda 2225.0
# Stock antes: -0.0
# Stock despues: 896.0
# Cantidad Producida 3121.0
# Item, cliente, horizonte temporal: (45, '102349', 9)
# Demanda 70.0
# Stock antes: 768.0
# Stock despues: 698.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (47, '105352', 9)
# Demanda 81.0
# Stock antes: 1992.0
# Stock despues: 1911.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (49, '100059', 9)
# Demanda 206.0
# Stock antes: 789.0
# Stock despues: 159.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (49, '100170', 9)
# Demanda 70.0
# Stock antes: 789.0
# Stock despues: 159.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (49, '101265', 9)
# Demanda 42.0
# Stock antes: 789.0
# Stock despues: 159.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (49, '101309', 9)
# Demanda 136.0
# Stock antes: 789.0
# Stock despues: 159.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (49, '101316', 9)
# Demanda 45.0
# Stock antes: 789.0
# Stock despues: 159.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (49, '101467', 9)
# Demanda 58.0
# Stock antes: 789.0
# Stock despues: 159.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (49, '104065', 9)
# Demanda 17.0
# Stock antes: 789.0
# Stock despues: 159.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (49, '104255', 9)
# Demanda 56.0
# Stock antes: 789.0
# Stock despues: 159.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (50, '105352', 9)
# Demanda 973.0
# Stock antes: 2376.0
# Stock despues: 1403.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (52, '105352', 9)
# Demanda 99.0
# Stock antes: 199.0
# Stock despues: 100.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (53, '101596', 9)
# NO SE SATISFACE
# ------------------------------------------
# Item, cliente, horizonte temporal: (3, '101695', 10)
# Demanda 160.0
# Stock antes: 883.0
# Stock despues: 723.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (4, '777772', 10)
# Demanda 240.0
# Stock antes: -0.0
# Stock despues: -0.0
# Cantidad Producida 240.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (23, '001301', 10)
# Demanda 62.0
# Stock antes: 1273.0
# Stock despues: 1116.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '100968', 10)
# Demanda 95.0
# Stock antes: 1273.0
# Stock despues: 1116.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (26, '105667', 10)
# Demanda 109.0
# Stock antes: 368.0
# Stock despues: 259.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (35, '100818', 10)
# Demanda 121.0
# Stock antes: 467.0
# Stock despues: 346.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (36, '777774', 10)
# Demanda 210.0
# Stock antes: 2168.0
# Stock despues: 1958.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (37, '101695', 10)
# Demanda 124.0
# Stock antes: 521.0
# Stock despues: 397.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (38, '101528', 10)
# Demanda 36.0
# Stock antes: 617.0
# Stock despues: 581.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '101826', 10)
# Demanda 434.0
# Stock antes: -0.0
# Stock despues: 276.0
# Cantidad Producida 2703.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105542', 10)
# Demanda 776.0
# Stock antes: -0.0
# Stock despues: 276.0
# Cantidad Producida 2703.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105667', 10)
# Demanda 455.0
# Stock antes: -0.0
# Stock despues: 276.0
# Cantidad Producida 2703.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '500090', 10)
# Demanda 762.0
# Stock antes: -0.0
# Stock despues: 276.0
# Cantidad Producida 2703.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (42, '777776', 10)
# Demanda 77.0
# Stock antes: 77.0
# Stock despues: 0.0
# Cantidad Producida -0.0
# Item, cliente, horizonte temporal: (43, '777777', 10)
# Demanda 69.0
# Stock antes: 896.0
# Stock despues: 827.0
# Cantidad Producida -0.0
# Item, cliente, horizonte temporal: (49, '101775', 10)
# Demanda 22.0
# Stock antes: 159.0
# Stock despues: 137.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (50, '105352', 10)
# Demanda 1139.0
# Stock antes: 1403.0
# Stock despues: 264.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (51, '001519', 10)
# Demanda 140.0
# Stock antes: 354.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 32.0
# Cantidad comprada previamente que llega ahora 32.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '001541', 10)
# Demanda 30.0
# Stock antes: 354.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 32.0
# Cantidad comprada previamente que llega ahora 32.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '001556', 10)
# Demanda 23.0
# Stock antes: 354.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 32.0
# Cantidad comprada previamente que llega ahora 32.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101400', 10)
# Demanda 12.0
# Stock antes: 354.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 32.0
# Cantidad comprada previamente que llega ahora 32.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101755', 10)
# Demanda 142.0
# Stock antes: 354.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 32.0
# Cantidad comprada previamente que llega ahora 32.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101868', 10)
# Demanda 27.0
# Stock antes: 354.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 32.0
# Cantidad comprada previamente que llega ahora 32.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '104230', 10)
# Demanda 12.0
# Stock antes: 354.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 32.0
# Cantidad comprada previamente que llega ahora 32.0
# Lead time 0
# Item, cliente, horizonte temporal: (52, '105352', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '100078', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101142', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101467', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101507', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101559', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101647', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101842', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101861', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '102067', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '103912', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '105343', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '105393', 10)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '105807', 10)
# NO SE SATISFACE
# ------------------------------------------
# Item, cliente, horizonte temporal: (1, '001308', 11)
# Demanda 80.0
# Stock antes: 287.0
# Stock despues: 0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (1, '001370', 11)
# Demanda 47.0
# Stock antes: 287.0
# Stock despues: 0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (1, '100892', 11)
# Demanda 160.0
# Stock antes: 287.0
# Stock despues: 0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (4, '777772', 11)
# Demanda 44.0
# Stock antes: -0.0
# Stock despues: 0.0
# Cantidad Producida 44.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (23, '000006', 11)
# Demanda 40.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '000048', 11)
# Demanda 16.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '000051', 11)
# Demanda 54.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '001070', 11)
# Demanda 263.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '001103', 11)
# Demanda 110.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '001213', 11)
# Demanda 132.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '001226', 11)
# Demanda 102.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '001297', 11)
# Demanda 100.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '001423', 11)
# Demanda 47.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101237', 11)
# Demanda 21.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101275', 11)
# Demanda 102.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101444', 11)
# Demanda 35.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '101585', 11)
# Demanda 41.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (23, '104031', 11)
# Demanda 53.0
# Stock antes: 1116.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (24, '101420', 11)
# Demanda 238.0
# Stock antes: 238.0
# Stock despues: 0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (25, '777773', 11)
# Demanda 220.0
# Stock antes: 1394.0
# Stock despues: 1174.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (36, '777774', 11)
# Demanda 1288.0
# Stock antes: 1958.0
# Stock despues: 670.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (37, '101695', 11)
# Demanda 37.0
# Stock antes: 397.0
# Stock despues: 360.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (38, '101528', 11)
# Demanda 54.0
# Stock antes: 581.0
# Stock despues: 527.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '101826', 11)
# Demanda 29.0
# Stock antes: 276.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105542', 11)
# Demanda 126.0
# Stock antes: 276.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105667', 11)
# Demanda 16.0
# Stock antes: 276.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '500090', 11)
# Demanda 105.0
# Stock antes: 276.0
# Stock despues: -0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (43, '777777', 11)
# Demanda 428.0
# Stock antes: 827.0
# Stock despues: 399.0
# Cantidad Producida -0.0
# Item, cliente, horizonte temporal: (45, '102349', 11)
# Demanda 698.0
# Stock antes: 698.0
# Stock despues: 0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (46, '777778', 11)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (50, '105352', 11)
# Demanda 264.0
# Stock antes: 264.0
# Stock despues: 0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (51, '001010', 11)
# Demanda 111.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 181.0
# Cantidad comprada previamente que llega ahora 181.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101256', 11)
# Demanda 45.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 181.0
# Cantidad comprada previamente que llega ahora 181.0
# Lead time 0
# Item, cliente, horizonte temporal: (51, '101874', 11)
# Demanda 25.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Cantidad Comprada 181.0
# Cantidad comprada previamente que llega ahora 181.0
# Lead time 0
# Item, cliente, horizonte temporal: (52, '105352', 11)
# NO SE SATISFACE
# ------------------------------------------
# Item, cliente, horizonte temporal: (3, '101695', 12)
# Demanda 968.0
# Stock antes: 723.0
# Stock despues: 0.0
# Cantidad Producida 245.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (23, '104190', 12)
# Demanda 139.0
# Stock antes: -0.0
# Stock despues: 0.0
# Cantidad Producida 139.0
# Cantidad Comprada -0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 0
# Item, cliente, horizonte temporal: (26, '101826', 12)
# Demanda 247.0
# Stock antes: 259.0
# Stock despues: 12.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (36, '777774', 12)
# Demanda 670.0
# Stock antes: 670.0
# Stock despues: 0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (37, '101695', 12)
# Demanda 360.0
# Stock antes: 360.0
# Stock despues: 0.0
# Cantidad Producida -0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '101826', 12)
# Demanda 588.0
# Stock antes: -0.0
# Stock despues: 0.0
# Cantidad Producida 2293.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105542', 12)
# Demanda 586.0
# Stock antes: -0.0
# Stock despues: 0.0
# Cantidad Producida 2293.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '105667', 12)
# Demanda 403.0
# Stock antes: -0.0
# Stock despues: 0.0
# Cantidad Producida 2293.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (40, '500090', 12)
# Demanda 716.0
# Stock antes: -0.0
# Stock despues: 0.0
# Cantidad Producida 2293.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (41, '101382', 12)
# Demanda 31.0
# Stock antes: 146.0
# Stock despues: 40.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (41, '102349', 12)
# Demanda 75.0
# Stock antes: 146.0
# Stock despues: 40.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (43, '777777', 12)
# Demanda 399.0
# Stock antes: 399.0
# Stock despues: 0.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (48, '101986', 12)
# Demanda 51.0
# Stock antes: 1534.0
# Stock despues: 1483.0
# Cantidad Producida 0.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora 0.0
# Lead time 6
# Item, cliente, horizonte temporal: (50, '105352', 12)
# Demanda 984.0
# Stock antes: 0.0
# Stock despues: 0.0
# Cantidad Producida 984.0
# Cantidad Comprada 0.0
# Cantidad comprada previamente que llega ahora -0.0
# Lead time 6
# Item, cliente, horizonte temporal: (52, '105352', 12)
# Demanda 55.0
# Stock antes: 100.0
# Stock despues: 45.0
# Cantidad Producida 0.0
# Item, cliente, horizonte temporal: (53, '101012', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101175', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101177', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101537', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101555', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101564', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101715', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '101879', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '104236', 12)
# NO SE SATISFACE
# Item, cliente, horizonte temporal: (53, '105378', 12)
# NO SE SATISFACE
# ------------------------------------------

# %%
for t in range(1,len(T)):
    for i in K2+K3:
        if z2[i,t].X!=0:
            print(f"Item, horizonte temporal {i, t}")
            print(f"Cantidad comprada {y[i,t].X}")
            print(f"Lead Time {lt[i]}")
            print(f"MOQ {MOQ2[i]}")
print("------------------------------------------")

# %%
for t in range(1,len(T)):
    for i in K1+K3:
        if z1[i,t].X!=0:
            print(f"Item, horizonte temporal {i, t}")
            print(f"Cantidad producida {x[i,t].X}")
            print(f"MOQ {MOQ1[i]}")
        else:
            if x[i,t].X != 0:
                print(f"No debería producir {i, t}")
                print(f"Cantidad producida {x[i,t].X}")

# %%
NoSatisfecha = 0
totalPedidos = 0
udsNoSatisfecha = 0
totalUds = 0
for t in range(1, len(T)):
    for i in LEVEL0:
        for r in R:
            if D[t][item_indices[i],customer_indices[r]] != 0:
                if w[i, r, t].X == 0:
                    NoSatisfecha += 1
                    udsNoSatisfecha += D[t][item_indices[i],customer_indices[r]]
                totalPedidos += 1
                totalUds += D[t][item_indices[i],customer_indices[r]]


print(udsNoSatisfecha/totalUds*100)
print(NoSatisfecha/totalPedidos*100)
print(modelo.getAttr("ObjVal"))

# %%
modelo.close()
env.close()
